# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "Name": ["Ayesha", "Ahmed", "Ali", "Murtaza"],
    "Age": [21, 25, 28, 28],
    "Gender": ["female", "male", "male", "male"]
})
# print(df["Age"].max())
print(df.describe())
# Out:
#              Age
# count   4.000000
# mean   25.500000
# std     3.316625
# min    21.000000
# 25%    24.000000
# 50%    26.500000
# 75%    28.000000
# max    28.000000

# %%
url = "https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv"

dataset = pd.read_csv(url,
    index_col=0,
    parse_dates=["HIRE_DATE"],
    date_format="%m/%d/%Y")

# %%
dataset.dtypes

dataset.info()
# dataset.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 50 entries, 198 to 140
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FIRST_NAME      50 non-null     str
#  1   LAST_NAME       50 non-null     str
#  2   EMAIL           50 non-null     str
#  3   PHONE_NUMBER    50 non-null     str
#  4   HIRE_DATE       50 non-null     str
#  5   JOB_ID          50 non-null     str
#  6   SALARY          50 non-null     int64
#  7   COMMISSION_PCT  50 non-null     str
#  8   MANAGER_ID      50 non-null     str
#  9   DEPARTMENT_ID   50 non-null     int64
# dtypes: int64(2), str(8)
# memory usage: 4.3 KB

# %%
pdSeries = pd.Series([21, 22, 28], name="Ages")
print(pdSeries.max())
# Out:
# 28

# %%
emailAndPhone = dataset[["EMAIL", "PHONE_NUMBER"]]
print(emailAndPhone.head(5).shape)
# Out:
# (5, 2)

# %%
salaryAbove25 = dataset[(dataset["DEPARTMENT_ID"]==50) | (dataset["DEPARTMENT_ID"]==60)]
print(salaryAbove25.head())
# Out:
#             FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE    JOB_ID  \
# EMPLOYEE_ID
# 198             Donald  OConnell  DOCONNEL  650.507.9833  21-JUN-07  SH_CLERK
# 199            Douglas     Grant    DGRANT  650.507.9844  13-JAN-08  SH_CLERK
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  03-JAN-06   IT_PROG
# 104              Bruce     Ernst    BERNST  590.423.4568  21-MAY-07   IT_PROG
# 105              David    Austin   DAUSTIN  590.423.4569  25-JUN-05   IT_PROG
#
#              SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# EMPLOYEE_ID
# 198            2600             -         124             50
# 199            2600             -         124             50
# 103            9000             -         102             60
# 104            6000             -         103             60
# 105            4800             -         103             60

# %%
dataset.iloc[0:3, 1] = "anonymous"
dataset.head()
# Out:
#             FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# EMPLOYEE_ID
# 198             Donald  anonymous  DOCONNEL  650.507.9833  21-JUN-07
# 199            Douglas  anonymous    DGRANT  650.507.9844  13-JAN-08
# 200           Jennifer  anonymous   JWHALEN  515.123.4444  17-SEP-03
# 201            Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 202                Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#                JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# EMPLOYEE_ID
# 198          SH_CLERK    2600             -         124             50
# 199          SH_CLERK    2600             -         124             50
# 200           AD_ASST    4400             -         101             10
# 201            MK_MAN   13000             -         100             20
# 202            MK_REP    6000             -         201             20

# %%
# dataset.plot()
# dataset.head()
# dataset[["SALARY", "DEPARTMENT_ID"]].plot.box()

dataset[["SALARY", "DEPARTMENT_ID"]].plot.area(figsize=(12,4), subplots=True)

plt.show()

# %%
dataset.plot.scatter(x="SALARY", y="DEPARTMENT_ID", alpha=0.5)

plt.show()

# %%
dataset.plot.area(figsize=(8, 2), subplots=True)

plt.show()

# %%
dataset.plot.area(figsize=(12,4), subplots=True)
fig, axs=plt.subplots(figsize=(12,4))
dataset.plot.area(ax=axs)

axs.set_ylabel("salary")

fig.savefig("salary_deptGraph.png")

plt.show()

# %%
dataset["EMAIL_NEW"] = dataset["EMAIL"]

# dataset.columns
# dataset.head(3)

dataset_renamed = dataset.rename(
    columns={
    "EMAIL": "Employee_Email",
    "FIRST_NAME": "Emp_First_Name"
})

dataset_renamed.rename(columns=str.lower)
dataset_renamed.head()
# Out:
#             Emp_First_Name  LAST_NAME Employee_Email  PHONE_NUMBER  HIRE_DATE  \
# EMPLOYEE_ID
# 198                 Donald  anonymous       DOCONNEL  650.507.9833  21-JUN-07
# 199                Douglas  anonymous         DGRANT  650.507.9844  13-JAN-08
# 200               Jennifer  anonymous        JWHALEN  515.123.4444  17-SEP-03
# 201                Michael  Hartstein       MHARTSTE  515.123.5555  17-FEB-04
# 202                    Pat        Fay           PFAY  603.123.6666  17-AUG-05
#
#                JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  \
# EMPLOYEE_ID
# 198          SH_CLERK    2600             -         124             50
# 199          SH_CLERK    2600             -         124             50
# 200           AD_ASST    4400             -         101             10
# 201            MK_MAN   13000             -         100             20
# 202            MK_REP    6000             -         201             20
#
#             EMAIL_NEW
# EMPLOYEE_ID
# 198          DOCONNEL
# 199            DGRANT
# 200           JWHALEN
# 201          MHARTSTE
# 202              PFAY

# %%
# dataset.index
# len(dataset["FIRST_NAME"])
# set(dataset["FIRST_NAME"])

# dataset["FIRST_NAME"].value_counts()
# dataset["FIRST_NAME"].count()

# dataset.sort_values(by="DEPARTMENT_ID", ascending=True)

# dataset.iloc[1]["FIRST_NAME"]

# dataset[(dataset['DEPARTMENT_ID']== 50) & (dataset['SALARY'] < 2500) ]

# dataset[~dataset["EMAIL"].str.startswith("A")]

# dataset.loc[dataset["FIRST_NAME"]== "Pat", "EMAIL"]= "PATEMAIL"
# dataset[dataset["FIRST_NAME"]=="Pat"]

dataset["FIRST_NAME"] = dataset["FIRST_NAME"].str.lower()

# %%
# dataset.drop(23)
# dataset.fillna({"COMMISSION_PCT": 0}, inplace=True)
# dataset.dropna()

#creates new one
# dataset["COMISSION_PCT"] = dataset['COMMISSION_PCT']=0

# dataset.loc[dataset["COMMISSION_PCT"] == "-", "COMMISSION_PCT"] = 0

# dataset["COMMISSION_PCT"] = dataset["COMMISSION_PCT"].astype(str).str.strip()
# dataset["COMMISSION_PCT"].replace("-", 0, inplace=True)

dataset.groupby("MANAGER_ID")["DEPARTMENT_ID"].max()
# Out:
# MANAGER_ID
#  -      90
# 100     90
# 101    110
# 102     60
# 103     60
# 108    100
# 114     30
# 120     50
# 121     50
# 122     50
# 123     50
# 124     50
# 201     20
# 205    110
# Name: DEPARTMENT_ID, dtype: int64
